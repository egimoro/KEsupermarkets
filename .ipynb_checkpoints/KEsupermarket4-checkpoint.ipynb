# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create a data frame of supermarkets

df = pd.DataFrame({'Supermarket': np.random.choice(['acacia', 'chandarana',
                  'tuskys', 'nakumatt', 'uchumi', 'eastmatt', 'ukwala',
                   'fairway', 'tumaini'], size=1000),
                   'Total paid': np.random.randint(70, 13000, size=1000),
                   'type': np.random.choice(['cash', 'card', 'mpesa'],
                                            size=1000)})

df
# Out:
#     Supermarket  Total paid   type
# 0       tumaini        8558   card
# 1      nakumatt       11220  mpesa
# 2       tumaini       12045  mpesa
# 3        acacia        4497   cash
# 4        uchumi        8731   cash
# ..          ...         ...    ...
# 995      uchumi        6475   card
# 996     fairway        9026   cash
# 997      acacia        9989  mpesa
# 998    eastmatt        8640   cash
# 999      tuskys        1717   card
#
# [1000 rows x 3 columns]

# %%
# Read full dataset

Location = r'../KEsupermarkets/data.csv'

df = pd.read_csv(Location)

df
# Out:
#      supermarket  no_of_items  variation   total  paid  change  type food  \
# 0         acacia            1          1    90.0   100    10.0  cash  yes
# 1         acacia            1          1    90.0   500   410.0  cash  yes
# 2         acacia            3          1   270.0   300    30.0  cash  yes
# 3         acacia            3          1   137.0   200    63.0  cash  yes
# 4         acacia            1          1    75.0    80     5.0  cash  yes
# ...          ...          ...        ...     ...   ...     ...   ...  ...
# 1459      tuskys            4          3  1810.0  2000   190.0  cash   no
# 1460    nakumatt            2          3   516.0   516     0.0  card  yes
# 1461      tuskys            2          1   290.0   500   210.0  cash  yes
# 1462      tuskys            5          2   596.0  1000   404.0  cash  yes
# 1463    Eastmatt            2          2   120.0  2000  1880.0  cash  yes
#
#      snack beverage  ... day_type 24hr day_1 month    year hour item_no_cat  \
# 0       no       no  ...  weekend   no    20     5  2017.0   19           A
# 1       no       no  ...  weekend   no    20     5  2017.0   19           A
# 2       no       no  ...  weekend   no    20     5  2017.0   19           B
# 3       no       no  ...  weekend   no    20     5  2017.0   19           B
# 4       no       no  ...  weekend   no    20     5  2017.0   18           A
# ...    ...      ...  ...      ...  ...   ...   ...     ...  ...         ...
# 1459   yes       no  ...  weekday   no    15     6  2017.0   11           B
# 1460    no      yes  ...  weekday   no    17     7  2017.0   21           A
# 1461    no       no  ...  weekend   no    30     6  2017.0   21           A
# 1462    no       no  ...  weekday   no     8     5  2017.0   11           B
# 1463   yes       no  ...  weekday   no    23     6  2017.0   16           A
#
#      total_cat paid_cat change_cat
# 0            1        1          1
# 1            1        1          1
# 2            1        1          1
# 3            1        1          1
# 4            1        1          1
# ...        ...      ...        ...
# 1459         4        1          1
# 1460         1        1          1
# 1461         1        1          1
# 1462         1        1          1
# 1463         1        1          0
#
# [1464 rows x 32 columns]

# %%
# Find unit item price from total

price = (df['total']/df['no_of_items']).sum()

print('Total unit price item is: KSH ' + str(np.round(price, 2)))
# Out:
# Total unit price item is: KSH 163522.98

# %%
# Set seaborn graphs to a better style

sns.set(style='ticks')

# Group by location

Location = df.groupby('location').sum()

# Sort the value and get the second 10 locations

Location = Location.sort_values(by='no_of_items', ascending=False)[1:11]

# Create the plot

Location['no_of_items'].plot(kind='bar')

# Set the title and labels

plt.xlabel('Location')
plt.ylabel('Number of items')
plt.title('10 Locations with most items')

# Show the plot

plt.show()
