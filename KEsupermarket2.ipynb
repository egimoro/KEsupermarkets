# %%
# Import libraries

import pandas as pd 
import matplotlib.pyplot as plt # Library for plotting
from numpy import random
import numpy.random as np

# Create lists of supermarkets, number of items, and total paid

supermarkets = ['acacia', 'acacia', 'acacia', 'acacia', 'nakumatt', 'tuskys',
                'chandarana', 'nakumatt', 'nakumatt', 'nakumatt', 'nakumatt',
                'uchumui', 'naivas', 'naivas', 'naivas', 'naivas',
                'naivas', 'naivas', 'naivas', 'karrymart', 'karrymart']

no_of_items = [1, 2, 6, 8, 33, 44, 14, 6, 8, 9, 6, 5, 1,
               2, 3, 6, 7, 5, 8, 10, 23]

variation = [1, 1, 2, 2, 13, 6, 2, 1, 3, 1, 1, 4, 2, 3,
             1, 1, 3, 2, 1, 2, 1, 2, 2, 6]

total = [90, 70, 270, 137, 5611, 55, 7955, 780, 235, 13005, 431, 1000, 242,
         4926, 5439, 5439, 8110, 221, 584, 850, 90]

# Create a data set with a zip function

KEsupermarket = list(zip(supermarkets, no_of_items, variation, total))

# Run the script

KEsupermarket
# Out:
# [('acacia', 1, 1, 90),
#  ('acacia', 2, 1, 70),
#  ('acacia', 6, 2, 270),
#  ('acacia', 8, 2, 137),
#  ('nakumatt', 33, 13, 5611),
#  ('tuskys', 44, 6, 55),
#  ('chandarana', 14, 2, 7955),
#  ('nakumatt', 6, 1, 780),
#  ('nakumatt', 8, 3, 235),
#  ('nakumatt', 9, 1, 13005),
#  ('nakumatt', 6, 1, 431),
#  ('uchumui', 5, 4, 1000),
#  ('naivas', 1, 2, 242),
#  ('naivas', 2, 3, 4926),
#  ('naivas', 3, 1, 5439),
#  ('naivas', 6, 1, 5439),
#  ('naivas', 7, 3, 8110),
#  ('naivas', 5, 2, 221),
#  ('naivas', 8, 1, 584),
#  ('karrymart', 10, 2, 850),
#  ('karrymart', 23, 1, 90)]

# %%
# Create another object called datadrame

df = pd.DataFrame(data=KEsupermarket, columns=['supermarkets', 'no_of_items',
                  'variation', 'total'])

df
# Out:
#    supermarkets  no_of_items  variation  total
# 0        acacia            1          1     90
# 1        acacia            2          1     70
# 2        acacia            6          2    270
# 3        acacia            8          2    137
# 4      nakumatt           33         13   5611
# 5        tuskys           44          6     55
# 6    chandarana           14          2   7955
# 7      nakumatt            6          1    780
# 8      nakumatt            8          3    235
# 9      nakumatt            9          1  13005
# 10     nakumatt            6          1    431
# 11      uchumui            5          4   1000
# 12       naivas            1          2    242
# 13       naivas            2          3   4926
# 14       naivas            3          1   5439
# 15       naivas            6          1   5439
# 16       naivas            7          3   8110
# 17       naivas            5          2    221
# 18       naivas            8          1    584
# 19    karrymart           10          2    850
# 20    karrymart           23          1     90

# %%
# Create a new header with column names

df = pd.read_csv(Location, names=['supermarkets', 'no_of_items',
                                  'variation', 'total'])

df
# Out:
#     supermarkets  no_of_items  variation  total
# 0         acacia           38        NaN    NaN
# 1         naivas          353        NaN    NaN
# 2         naivas          610        NaN    NaN
# 3       nakumatt          954        NaN    NaN
# 4       nakumatt           38        NaN    NaN
# ..           ...          ...        ...    ...
# 995       naivas           55        NaN    NaN
# 996    karrymart          952        NaN    NaN
# 997       naivas          613        NaN    NaN
# 998      uchumui          422        NaN    NaN
# 999     nakumatt          213        NaN    NaN
#
# [1000 rows x 4 columns]

# %%
# Plot the dataframe

df['variation'].plot()

MaxValue = df['variation'].max()

MaxSupermarket = df['supermarkets'][df['variation'] == df['variation'
                    ].max()].values

Text = str(MaxValue) + " - " + MaxSupermarket

plt.annotate(Text, xy=(1, MaxValue), xytext=(8, 0), 
             xycoords=('axes fraction', 'data'), textcoords='offset points')

print("The most popular supermarket")

df[df['supermarkets'] == df['supermarkets'].max()]
# Out:
# The most popular supermarket
#     supermarkets  no_of_items  variation  total
# 26       uchumui          444        NaN    NaN
# 36       uchumui          182        NaN    NaN
# 57       uchumui          982        NaN    NaN
# 58       uchumui          356        NaN    NaN
# 61       uchumui          355        NaN    NaN
# 80       uchumui          660        NaN    NaN
# 86       uchumui          148        NaN    NaN
# 115      uchumui          663        NaN    NaN
# 120      uchumui          712        NaN    NaN
# 138      uchumui          674        NaN    NaN
# 149      uchumui           85        NaN    NaN
# 176      uchumui          422        NaN    NaN
# 244      uchumui          632        NaN    NaN
# 251      uchumui          695        NaN    NaN
# 261      uchumui          562        NaN    NaN
# 273      uchumui          413        NaN    NaN
# 279      uchumui          461        NaN    NaN
# 291      uchumui           58        NaN    NaN
# 297      uchumui          277        NaN    NaN
# 305      uchumui          398        NaN    NaN
# 308      uchumui          255        NaN    NaN
# 348      uchumui          661        NaN    NaN
# 452      uchumui           79        NaN    NaN
# 524      uchumui          211        NaN    NaN
# 554      uchumui          307        NaN    NaN
# 563      uchumui          695        NaN    NaN
# 611      uchumui          265        NaN    NaN
# 648      uchumui          428        NaN    NaN
# 719      uchumui          198        NaN    NaN
# 723      uchumui          209        NaN    NaN
# 728      uchumui           92        NaN    NaN
# 745      uchumui          489        NaN    NaN
# 749      uchumui          558        NaN    NaN
# 774      uchumui          134        NaN    NaN
# 783      uchumui          968        NaN    NaN
# 815      uchumui           40        NaN    NaN
# 832      uchumui          223        NaN    NaN
# 839      uchumui          340        NaN    NaN
# 845      uchumui          416        NaN    NaN
# 847      uchumui          125        NaN    NaN
# 886      uchumui           45        NaN    NaN
# 908      uchumui          707        NaN    NaN
# 914      uchumui          999        NaN    NaN
# 921      uchumui          294        NaN    NaN
# 976      uchumui          979        NaN    NaN
# 980      uchumui          610        NaN    NaN
# 998      uchumui          422        NaN    NaN

# %%
# Create another object called datadrame

df = pd.DataFrame(data=KEsupermarket, columns=['supermarkets', 'no_of_items',
                  'variation', 'total'])

df
# Out:
#    supermarkets  no_of_items  variation  total
# 0        acacia            1          1     90
# 1        acacia            2          1     70
# 2        acacia            6          2    270
# 3        acacia            8          2    137
# 4      nakumatt           33         13   5611
# 5        tuskys           44          6     55
# 6    chandarana           14          2   7955
# 7      nakumatt            6          1    780
# 8      nakumatt            8          3    235
# 9      nakumatt            9          1  13005
# 10     nakumatt            6          1    431
# 11      uchumui            5          4   1000
# 12       naivas            1          2    242
# 13       naivas            2          3   4926
# 14       naivas            3          1   5439
# 15       naivas            6          1   5439
# 16       naivas            7          3   8110
# 17       naivas            5          2    221
# 18       naivas            8          1    584
# 19    karrymart           10          2    850
# 20    karrymart           23          1     90

# %%
# Plot the dataframe

df['variation'].plot()

MaxValue = df['variation'].max()

MaxSupermarket = df['supermarkets'][df['variation'] == df['variation'
                    ].max()].values

Text = str(MaxValue) + " - " + MaxSupermarket

plt.annotate(Text, xy=(1, MaxValue), xytext=(8, 0), 
             xycoords=('axes fraction', 'data'), textcoords='offset points')

print("The most popular supermarket")

df[df['supermarkets'] == df['supermarkets'].max()]
# Out:
# The most popular supermarket
#    supermarkets  no_of_items  variation  total
# 11      uchumui            5          4   1000

# %%
df = pd.read_csv(Location, names=['Supermarkets', 'Total'])

df.head()
# Out:
#   Supermarkets  Total
# 0       acacia     38
# 1       naivas    353
# 2       naivas    610
# 3     nakumatt    954
# 4     nakumatt     38

# %%
# Print unique values

df['Supermarkets'].unique()
# Out:
# array(['acacia', 'naivas', 'nakumatt', 'karrymart', 'chandarana',
#        'uchumui', 'tuskys'], dtype=object)

# %%
df['Total'].plot.bar()

print('The most popular supermarket')

df.sort_values(by='Total', ascending=False)
# Out:
# The most popular supermarket
#     Supermarkets  Total
# 914      uchumui    999
# 370       acacia    998
# 732       naivas    998
# 143       acacia    996
# 333       acacia    995
# ..           ...    ...
# 139       naivas      5
# 555    karrymart      3
# 776     nakumatt      3
# 811       acacia      2
# 56        naivas      1
#
# [1000 rows x 2 columns]

# %%
df['Total'].max()
# Out:
# 999

# %%
df['Total'].plot.bar()

print('The most popular supermarket')

df.sort_values(by='Total', ascending=False)
# Out:
# The most popular supermarket
#     Supermarkets  Total
# 914      uchumui    999
# 370       acacia    998
# 732       naivas    998
# 143       acacia    996
# 333       acacia    995
# ..           ...    ...
# 139       naivas      5
# 555    karrymart      3
# 776     nakumatt      3
# 811       acacia      2
# 56        naivas      1
#
# [1000 rows x 2 columns]

# %%
df['Total'].plot.bar()

print('The most popular supermarket')

df.sort_values(by='Total', ascending=False)
# Out:
# The most popular supermarket
#     Supermarkets  Total
# 914      uchumui    999
# 370       acacia    998
# 732       naivas    998
# 143       acacia    996
# 333       acacia    995
# ..           ...    ...
# 139       naivas      5
# 555    karrymart      3
# 776     nakumatt      3
# 811       acacia      2
# 56        naivas      1
#
# [1000 rows x 2 columns]
