# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read full dataset

Location = r'../KEsupermarkets/data.csv'

df = pd.read_csv(Location)

df
# Out:
#      supermarket  no_of_items  variation   total  paid  change  type food  \
# 0         acacia            1          1    90.0   100    10.0  cash  yes
# 1         acacia            1          1    90.0   500   410.0  cash  yes
# 2         acacia            3          1   270.0   300    30.0  cash  yes
# 3         acacia            3          1   137.0   200    63.0  cash  yes
# 4         acacia            1          1    75.0    80     5.0  cash  yes
# ...          ...          ...        ...     ...   ...     ...   ...  ...
# 1459      tuskys            4          3  1810.0  2000   190.0  cash   no
# 1460    nakumatt            2          3   516.0   516     0.0  card  yes
# 1461      tuskys            2          1   290.0   500   210.0  cash  yes
# 1462      tuskys            5          2   596.0  1000   404.0  cash  yes
# 1463    Eastmatt            2          2   120.0  2000  1880.0  cash  yes
#
#      snack beverage  ... day_type 24hr day_1 month    year hour item_no_cat  \
# 0       no       no  ...  weekend   no    20     5  2017.0   19           A
# 1       no       no  ...  weekend   no    20     5  2017.0   19           A
# 2       no       no  ...  weekend   no    20     5  2017.0   19           B
# 3       no       no  ...  weekend   no    20     5  2017.0   19           B
# 4       no       no  ...  weekend   no    20     5  2017.0   18           A
# ...    ...      ...  ...      ...  ...   ...   ...     ...  ...         ...
# 1459   yes       no  ...  weekday   no    15     6  2017.0   11           B
# 1460    no      yes  ...  weekday   no    17     7  2017.0   21           A
# 1461    no       no  ...  weekend   no    30     6  2017.0   21           A
# 1462    no       no  ...  weekday   no     8     5  2017.0   11           B
# 1463   yes       no  ...  weekday   no    23     6  2017.0   16           A
#
#      total_cat paid_cat change_cat
# 0            1        1          1
# 1            1        1          1
# 2            1        1          1
# 3            1        1          1
# 4            1        1          1
# ...        ...      ...        ...
# 1459         4        1          1
# 1460         1        1          1
# 1461         1        1          1
# 1462         1        1          1
# 1463         1        1          0
#
# [1464 rows x 32 columns]

# %%
# Count how many items are food

food_item = df[df.food == 'yes']

len(food_item)
# Out:
# 718

# %%
# Set the 'type_market' column as the index of the dataframe

df.set_index('type_market', inplace=True)

# Print only the beverage column

df.beverage
# Out:
# type_market
# small     no
# small     no
# small     no
# small     no
# small     no
#         ...
# chain     no
# chain    yes
# chain     no
# chain     no
# chain     no
# Name: beverage, Length: 1464, dtype: object

# %%
# Print the columns 'mall' and 'bevarage'

df[['mall', 'beverage']]
# Out:
#             mall beverage
# type_market
# small         no       no
# small         no       no
# small         no       no
# small         no       no
# small         no       no
# ...          ...      ...
# chain        yes       no
# chain        yes      yes
# chain         no       no
# chain        yes       no
# chain         no       no
#
# [1464 rows x 2 columns]

# %%
# Select the 'Supermarket', 'Change', 'Type' columns from small and chain

df.loc[['small', 'chain'], ['supermarket', 'change', 'type']]
# Out:
#             supermarket  change  type
# type_market
# small            acacia    10.0  cash
# small            acacia   410.0  cash
# small            acacia    30.0  cash
# small            acacia    63.0  cash
# small            acacia     5.0  cash
# ...                 ...     ...   ...
# chain            tuskys   190.0  cash
# chain          nakumatt     0.0  card
# chain            tuskys   210.0  cash
# chain            tuskys   404.0  cash
# chain          Eastmatt  1880.0  cash
#
# [1427 rows x 3 columns]

# %%
# Select the rows 3 to 7 and the columns 3 to 6

df.iloc[2:7, 2:6]
# Out:
#              variation   total  paid  change
# type_market
# small                1   270.0   300    30.0
# small                1   137.0   200    63.0
# small                1    75.0    80     5.0
# chain                3  5611.0  5611     0.0
# small                1    55.0   100    45.0

# %%
# Select every row after the fourth and all columns

df.iloc[4:, :]
# Out:
#             supermarket  no_of_items  variation   total  paid  change   type  \
# type_market
# small            acacia            1          1    75.0    80     5.0   cash
# chain          nakumatt           22          3  5611.0  5611     0.0   card
# small            acacia            1          1    55.0   100    45.0   cash
# median       chandarana           32          3  7955.0  7955     0.0  mpesa
# chain          nakumatt            1          1   780.0  1000   220.0   cash
# ...                 ...          ...        ...     ...   ...     ...    ...
# chain            tuskys            4          3  1810.0  2000   190.0   cash
# chain          nakumatt            2          3   516.0   516     0.0   card
# chain            tuskys            2          1   290.0   500   210.0   cash
# chain            tuskys            5          2   596.0  1000   404.0   cash
# chain          Eastmatt            2          2   120.0  2000  1880.0   cash
#
#             food snack beverage  ... day_type 24hr day_1 month    year hour  \
# type_market                      ...
# small        yes    no       no  ...  weekend   no    20     5  2017.0   18
# chain        yes    no       no  ...  weekday  yes    24    12  2016.0   16
# small        yes    no       no  ...  weekend   no    20     5  2017.0   18
# median       yes    no       no  ...  weekday   no     3     1  2017.0   19
# chain         no    no       no  ...  weekday   no    27     3  2017.0   19
# ...          ...   ...      ...  ...      ...  ...   ...   ...     ...  ...
# chain         no   yes       no  ...  weekday   no    15     6  2017.0   11
# chain        yes    no      yes  ...  weekday   no    17     7  2017.0   21
# chain        yes    no       no  ...  weekend   no    30     6  2017.0   21
# chain        yes    no       no  ...  weekday   no     8     5  2017.0   11
# chain        yes   yes       no  ...  weekday   no    23     6  2017.0   16
#
#             item_no_cat total_cat paid_cat change_cat
# type_market
# small                 A         1        1          1
# chain                 B         0        2          1
# small                 A         1        1          1
# median                B         0        3          1
# chain                 A         1        1          1
# ...                 ...       ...      ...        ...
# chain                 B         4        1          1
# chain                 A         1        1          1
# chain                 A         1        1          1
# chain                 B         1        1          1
# chain                 A         1        1          0
#
# [1460 rows x 31 columns]

# %%
# Select every row up to the 4th row and all columns

df.iloc[:4, :]
# Out:
#             supermarket  no_of_items  variation  total  paid  change  type  \
# type_market
# small            acacia            1          1   90.0   100    10.0  cash
# small            acacia            1          1   90.0   500   410.0  cash
# small            acacia            3          1  270.0   300    30.0  cash
# small            acacia            3          1  137.0   200    63.0  cash
#
#             food snack beverage  ... day_type 24hr day_1 month    year hour  \
# type_market                      ...
# small        yes    no       no  ...  weekend   no    20     5  2017.0   19
# small        yes    no       no  ...  weekend   no    20     5  2017.0   19
# small        yes    no       no  ...  weekend   no    20     5  2017.0   19
# small        yes    no       no  ...  weekend   no    20     5  2017.0   19
#
#             item_no_cat total_cat paid_cat change_cat
# type_market
# small                 A         1        1          1
# small                 A         1        1          1
# small                 B         1        1          1
# small                 B         1        1          1
#
# [4 rows x 31 columns]

# %%
# Select the 3rd column up to the 7th column

df.iloc[:, 2:7]
# Out:
#              variation   total  paid  change  type
# type_market
# small                1    90.0   100    10.0  cash
# small                1    90.0   500   410.0  cash
# small                1   270.0   300    30.0  cash
# small                1   137.0   200    63.0  cash
# small                1    75.0    80     5.0  cash
# ...                ...     ...   ...     ...   ...
# chain                3  1810.0  2000   190.0  cash
# chain                3   516.0   516     0.0  card
# chain                1   290.0   500   210.0  cash
# chain                2   596.0  1000   404.0  cash
# chain                2   120.0  2000  1880.0  cash
#
# [1464 rows x 5 columns]

# %%
# Select rows where df.change is greater than 1500

df[df['change'] > 1500]
# Out:
#             supermarket  no_of_items  variation  total  paid  change  type  \
# type_market
# chain          Eastmatt            2          2  120.0  2000  1880.0  cash
#
#             food snack beverage  ... day_type 24hr day_1 month    year hour  \
# type_market                      ...
# chain        yes   yes       no  ...  weekday   no    23     6  2017.0   16
#
#             item_no_cat total_cat paid_cat change_cat
# type_market
# chain                 A         1        1          0
#
# [1 rows x 31 columns]

# %%
# Select rows where df.change is greater than 1500 or less than 150

df[(df['change'] > 1500) | (df['change'] < 150)]
# Out:
#             supermarket  no_of_items  variation   total  paid  change   type  \
# type_market
# small            acacia            1          1    90.0   100    10.0   cash
# small            acacia            3          1   270.0   300    30.0   cash
# small            acacia            3          1   137.0   200    63.0   cash
# small            acacia            1          1    75.0    80     5.0   cash
# chain          nakumatt           22          3  5611.0  5611     0.0   card
# ...                 ...          ...        ...     ...   ...     ...    ...
# chain            uchumi            1          1    70.0   200   130.0   cash
# chain            tuskys            2          3  1230.0  1230     0.0  mpesa
# chain            tuskys            1          1    90.0   100    10.0   cash
# chain          nakumatt            2          3   516.0   516     0.0   card
# chain          Eastmatt            2          2   120.0  2000  1880.0   cash
#
#             food snack beverage  ... day_type 24hr day_1 month    year hour  \
# type_market                      ...
# small        yes    no       no  ...  weekend   no    20     5  2017.0   19
# small        yes    no       no  ...  weekend   no    20     5  2017.0   19
# small        yes    no       no  ...  weekend   no    20     5  2017.0   19
# small        yes    no       no  ...  weekend   no    20     5  2017.0   18
# chain        yes    no       no  ...  weekday  yes    24    12  2016.0   16
# ...          ...   ...      ...  ...      ...  ...   ...   ...     ...  ...
# chain         no   yes       no  ...  weekend   no    23     9  2017.0   19
# chain        yes    no       no  ...  weekday   no    15     6  2017.0   19
# chain        yes    no       no  ...  weekday   no    15     6  2017.0   20
# chain        yes    no      yes  ...  weekday   no    17     7  2017.0   21
# chain        yes   yes       no  ...  weekday   no    23     6  2017.0   16
#
#             item_no_cat total_cat paid_cat change_cat
# type_market
# small                 A         1        1          1
# small                 B         1        1          1
# small                 B         1        1          1
# small                 A         1        1          1
# chain                 B         0        2          1
# ...                 ...       ...      ...        ...
# chain                 A         1        1          1
# chain                 A         1        1          1
# chain                 A         1        1          1
# chain                 A         1        1          1
# chain                 A         1        1          0
#
# [1056 rows x 31 columns]

# %%
# Select all the location not 'saika'

df[df['location'] != 'saika']
# Out:
#             supermarket  no_of_items  variation    total   paid  change  \
# type_market
# chain          nakumatt           22          3   5611.0   5611     0.0
# median       chandarana           32          3   7955.0   7955     0.0
# chain          nakumatt            1          1    780.0   1000   220.0
# chain            tuskys           33          6  13005.0  13001     0.0
# chain          nakumatt            2          1    431.0    500    68.0
# ...                 ...          ...        ...      ...    ...     ...
# chain            tuskys            4          3   1810.0   2000   190.0
# chain          nakumatt            2          3    516.0    516     0.0
# chain            tuskys            2          1    290.0    500   210.0
# chain            tuskys            5          2    596.0   1000   404.0
# chain          Eastmatt            2          2    120.0   2000  1880.0
#
#               type food snack beverage  ... day_type 24hr day_1 month    year  \
# type_market                             ...
# chain         card  yes    no       no  ...  weekday  yes    24    12  2016.0
# median       mpesa  yes    no       no  ...  weekday   no     3     1  2017.0
# chain         cash   no    no       no  ...  weekday   no    27     3  2017.0
# chain         card  yes    no       no  ...  weekday   no     7    12  2016.0
# chain         cash  yes    no      yes  ...  weekend   no    23     7  2016.0
# ...            ...  ...   ...      ...  ...      ...  ...   ...   ...     ...
# chain         cash   no   yes       no  ...  weekday   no    15     6  2017.0
# chain         card  yes    no      yes  ...  weekday   no    17     7  2017.0
# chain         cash  yes    no       no  ...  weekend   no    30     6  2017.0
# chain         cash  yes    no       no  ...  weekday   no     8     5  2017.0
# chain         cash  yes   yes       no  ...  weekday   no    23     6  2017.0
#
#             hour item_no_cat total_cat paid_cat change_cat
# type_market
# chain         16           B         0        2          1
# median        19           B         0        3          1
# chain         19           A         1        1          1
# chain          8           B         0        0          1
# chain         11           A         1        1          1
# ...          ...         ...       ...      ...        ...
# chain         11           B         4        1          1
# chain         21           A         1        1          1
# chain         21           A         1        1          1
# chain         11           B         1        1          1
# chain         16           A         1        1          0
#
# [1411 rows x 31 columns]

# %%
# Reset index

df.reset_index()
# Out:
#      type_market supermarket  no_of_items  variation   total  paid  change  \
# 0          small      acacia            1          1    90.0   100    10.0
# 1          small      acacia            1          1    90.0   500   410.0
# 2          small      acacia            3          1   270.0   300    30.0
# 3          small      acacia            3          1   137.0   200    63.0
# 4          small      acacia            1          1    75.0    80     5.0
# ...          ...         ...          ...        ...     ...   ...     ...
# 1459       chain      tuskys            4          3  1810.0  2000   190.0
# 1460       chain    nakumatt            2          3   516.0   516     0.0
# 1461       chain      tuskys            2          1   290.0   500   210.0
# 1462       chain      tuskys            5          2   596.0  1000   404.0
# 1463       chain    Eastmatt            2          2   120.0  2000  1880.0
#
#       type food snack  ... day_type 24hr day_1 month    year hour item_no_cat  \
# 0     cash  yes    no  ...  weekend   no    20     5  2017.0   19           A
# 1     cash  yes    no  ...  weekend   no    20     5  2017.0   19           A
# 2     cash  yes    no  ...  weekend   no    20     5  2017.0   19           B
# 3     cash  yes    no  ...  weekend   no    20     5  2017.0   19           B
# 4     cash  yes    no  ...  weekend   no    20     5  2017.0   18           A
# ...    ...  ...   ...  ...      ...  ...   ...   ...     ...  ...         ...
# 1459  cash   no   yes  ...  weekday   no    15     6  2017.0   11           B
# 1460  card  yes    no  ...  weekday   no    17     7  2017.0   21           A
# 1461  cash  yes    no  ...  weekend   no    30     6  2017.0   21           A
# 1462  cash  yes    no  ...  weekday   no     8     5  2017.0   11           B
# 1463  cash  yes   yes  ...  weekday   no    23     6  2017.0   16           A
#
#      total_cat paid_cat change_cat
# 0            1        1          1
# 1            1        1          1
# 2            1        1          1
# 3            1        1          1
# 4            1        1          1
# ...        ...      ...        ...
# 1459         4        1          1
# 1460         1        1          1
# 1461         1        1          1
# 1462         1        1          1
# 1463         1        1          0
#
# [1464 rows x 32 columns]

# %%
# Reset index

df.reset_index()
# Out:
#       time_type supermarket  no_of_items  variation   total  paid  change  \
# 0         night      acacia            1          1    90.0   100    10.0
# 1         night      acacia            1          1    90.0   500   410.0
# 2         night      acacia            3          1   270.0   300    30.0
# 3         night      acacia            3          1   137.0   200    63.0
# 4     afternoon      acacia            1          1    75.0    80     5.0
# ...         ...         ...          ...        ...     ...   ...     ...
# 1459    morning      tuskys            4          3  1810.0  2000   190.0
# 1460      night    nakumatt            2          3   516.0   516     0.0
# 1461      night      tuskys            2          1   290.0   500   210.0
# 1462    morning      tuskys            5          2   596.0  1000   404.0
# 1463    evening    Eastmatt            2          2   120.0  2000  1880.0
#
#       type food snack  ...       day 24hr day_1 month    year hour  \
# 0     cash  yes    no  ...  saturday   no    20     5  2017.0   19
# 1     cash  yes    no  ...  saturday   no    20     5  2017.0   19
# 2     cash  yes    no  ...  saturday   no    20     5  2017.0   19
# 3     cash  yes    no  ...  saturday   no    20     5  2017.0   19
# 4     cash  yes    no  ...  saturday   no    20     5  2017.0   18
# ...    ...  ...   ...  ...       ...  ...   ...   ...     ...  ...
# 1459  cash   no   yes  ...  Thursday   no    15     6  2017.0   11
# 1460  card  yes    no  ...    Monday   no    17     7  2017.0   21
# 1461  cash  yes    no  ...    Sunday   no    30     6  2017.0   21
# 1462  cash  yes    no  ...    Monday   no     8     5  2017.0   11
# 1463  cash  yes   yes  ...    Friday   no    23     6  2017.0   16
#
#      item_no_cat total_cat paid_cat change_cat
# 0              A         1        1          1
# 1              A         1        1          1
# 2              B         1        1          1
# 3              B         1        1          1
# 4              A         1        1          1
# ...          ...       ...      ...        ...
# 1459           B         4        1          1
# 1460           A         1        1          1
# 1461           A         1        1          1
# 1462           B         1        1          1
# 1463           A         1        1          0
#
# [1464 rows x 30 columns]

# %%
# Set column 'time_type' as index

try:
    df.set_index('time_type', inplace=True)
except Exception:
    print('Something wrong')

df
# Out:
# Something wrong
#           supermarket  no_of_items  variation   total  paid  change  type  \
# time_type
# night          acacia            1          1    90.0   100    10.0  cash
# night          acacia            1          1    90.0   500   410.0  cash
# night          acacia            3          1   270.0   300    30.0  cash
# night          acacia            3          1   137.0   200    63.0  cash
# afternoon      acacia            1          1    75.0    80     5.0  cash
# ...               ...          ...        ...     ...   ...     ...   ...
# morning        tuskys            4          3  1810.0  2000   190.0  cash
# night        nakumatt            2          3   516.0   516     0.0  card
# night          tuskys            2          1   290.0   500   210.0  cash
# morning        tuskys            5          2   596.0  1000   404.0  cash
# evening      Eastmatt            2          2   120.0  2000  1880.0  cash
#
#           food snack beverage  ...       day 24hr day_1 month    year hour  \
# time_type                      ...
# night      yes    no       no  ...  saturday   no    20     5  2017.0   19
# night      yes    no       no  ...  saturday   no    20     5  2017.0   19
# night      yes    no       no  ...  saturday   no    20     5  2017.0   19
# night      yes    no       no  ...  saturday   no    20     5  2017.0   19
# afternoon  yes    no       no  ...  saturday   no    20     5  2017.0   18
# ...        ...   ...      ...  ...       ...  ...   ...   ...     ...  ...
# morning     no   yes       no  ...  Thursday   no    15     6  2017.0   11
# night      yes    no      yes  ...    Monday   no    17     7  2017.0   21
# night      yes    no       no  ...    Sunday   no    30     6  2017.0   21
# morning    yes    no       no  ...    Monday   no     8     5  2017.0   11
# evening    yes   yes       no  ...    Friday   no    23     6  2017.0   16
#
#           item_no_cat total_cat paid_cat change_cat
# time_type
# night               A         1        1          1
# night               A         1        1          1
# night               B         1        1          1
# night               B         1        1          1
# afternoon           A         1        1          1
# ...               ...       ...      ...        ...
# morning             B         4        1          1
# night               A         1        1          1
# night               A         1        1          1
# morning             B         1        1          1
# evening             A         1        1          0
#
# [1464 rows x 29 columns]

# %%
# Select rows morning and evening

df.loc[['morning', 'evening']]
# Out:
#           supermarket  no_of_items  variation    total   paid  change   type  \
# time_type
# morning        tuskys           33          6  13005.0  13001     0.0   card
# morning      nakumatt            2          1    431.0    500    68.0   cash
# morning      nakumatt            3          1   1000.0   1000     0.0   cash
# morning      nakumatt            1          1   2420.0   2460     0.0   card
# morning      nakumatt           12          2   4926.0   4926     0.0   card
# ...               ...          ...        ...      ...    ...     ...    ...
# evening      nakumatt            4          1    526.0    526     0.0  mpesa
# evening     karrymart            1          1     30.0     50    20.0   cash
# evening      nakumatt            1          1     49.0    100    51.0   cash
# evening      nakumatt            2          1     78.0     78     0.0   cash
# evening      Eastmatt            2          2    120.0   2000  1880.0   cash
#
#           food snack beverage  ...        day 24hr day_1 month    year hour  \
# time_type                      ...
# morning    yes    no       no  ...  wednesday   no     7    12  2016.0    8
# morning    yes    no      yes  ...   saturday   no    23     7  2016.0   11
# morning     no    no       no  ...   saturday  yes    20     8  2016.0    9
# morning     no    no       no  ...     friday   no    11    11  2016.0    8
# morning    yes    no       no  ...     friday   no    11    11  2016.0    8
# ...        ...   ...      ...  ...        ...  ...   ...   ...     ...  ...
# evening    yes    no       no  ...   Thursday   no    12    11  2015.0   17
# evening     no    no       no  ...    Tuesday   no    23     5  2018.0   16
# evening    yes    no       no  ...    Tuesday   no    27     6  2017.0   18
# evening     no    no      yes  ...   Thursday  yes    29     6  2017.0   18
# evening    yes   yes       no  ...     Friday   no    23     6  2017.0   16
#
#           item_no_cat total_cat paid_cat change_cat
# time_type
# morning             B         0        0          1
# morning             A         1        1          1
# morning             B         1        1          1
# morning             A         2        4          1
# morning             B         0        0          1
# ...               ...       ...      ...        ...
# evening             B         1        1          1
# evening             A         1        1          1
# evening             A         1        1          1
# evening             A         1        1          1
# evening             A         1        1          0
#
# [752 rows x 29 columns]

# %%
# Select the third cell in the row afternoon

df.loc[['afternoon']].iloc[:, 2]
# Out:
# time_type
# afternoon    1
# afternoon    3
# afternoon    1
# afternoon    1
# afternoon    2
#             ..
# afternoon    2
# afternoon    1
# afternoon    1
# afternoon    1
# afternoon    2
# Name: variation, Length: 395, dtype: int64

# %%
# Select the third cell down in the column named variation

df.loc[:, ['variation']].iloc[2]
# Out:
# variation    1
# Name: night, dtype: int64

# %%
# Select rows afternoon and morning from the columns total to snack

s = df.loc[['afternoon', 'morning']].iloc[:, 3:9]

s
# Out:
#             total  paid  change  type food snack
# time_type
# afternoon    75.0    80     5.0  cash  yes    no
# afternoon  5611.0  5611     0.0  card  yes    no
# afternoon    55.0   100    45.0  cash  yes    no
# afternoon   235.0   500   265.0  cash   no    no
# afternoon   242.0   500   258.0  cash   no    no
# ...           ...   ...     ...   ...  ...   ...
# morning     140.0   500   360.0  cash   no    no
# morning     134.0   150    16.0  cash  yes    no
# morning     105.0   105     0.0  cash   no   yes
# morning    1810.0  2000   190.0  cash   no   yes
# morning     596.0  1000   404.0  cash  yes    no
#
# [743 rows x 6 columns]

# %%
# Group selected dataset by column snack

s.groupby('snack').sum()
# Out:
#            total    paid    change
# snack
# no     127236.75  200411  75637.53
# yes     86800.00  125744  40554.25

# %%
# Group by the snack the mean of columns with numeric values

sg = s.groupby('snack').mean()

sg
# Out:
#             total        paid      change
# snack
# no     259.666837  409.002041  154.362306
# yes    343.083004  497.011858  160.293478
